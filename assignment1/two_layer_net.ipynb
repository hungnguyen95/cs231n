# %% [markdown]
# # Implementing a Neural Network
# In this exercise we will develop a neural network with fully-connected layers to perform classification, and test it out on the CIFAR-10 dataset.

# %%
# A bit of setup

from __future__ import print_function
import numpy as np
import matplotlib.pyplot as plt

from cs231n.classifiers.neural_net import TwoLayerNet

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %% [markdown]
# We will use the class `TwoLayerNet` in the file `cs231n/classifiers/neural_net.py` to represent instances of our network. The network parameters are stored in the instance variable `self.params` where keys are string parameter names and values are numpy arrays. Below, we initialize toy data and a toy model that we will use to develop your implementation.

# %%
# Create a small net and some toy data to check your implementations.
# Note that we set the random seed for repeatable experiments.

input_size = 4
hidden_size = 10
num_classes = 3
num_inputs = 5

def init_toy_model():
    np.random.seed(0)
    return TwoLayerNet(input_size, hidden_size, num_classes, std=1e-1)

def init_toy_data():
    np.random.seed(1)
    X = 10 * np.random.randn(num_inputs, input_size)
    y = np.array([0, 1, 2, 2, 1])
    return X, y

net = init_toy_model()
X, y = init_toy_data()

# %% [markdown]
# # Forward pass: compute scores
# Open the file `cs231n/classifiers/neural_net.py` and look at the method `TwoLayerNet.loss`. This function is very similar to the loss functions you have written for the SVM and Softmax exercises: It takes the data and weights and computes the class scores, the loss, and the gradients on the parameters.
#
# Implement the first part of the forward pass which uses the weights and biases to compute the scores for all inputs.

# %%
scores = net.loss(X)
print('Your scores:')
print(scores)
print()
print('correct scores:')
correct_scores = np.asarray([
  [-0.81233741, -1.27654624, -0.70335995],
  [-0.17129677, -1.18803311, -0.47310444],
  [-0.51590475, -1.01354314, -0.8504215 ],
  [-0.15419291, -0.48629638, -0.52901952],
  [-0.00618733, -0.12435261, -0.15226949]])
print(correct_scores)
print()

# The difference should be very small. We get < 1e-7
print('Difference between your scores and correct scores:')
print(np.sum(np.abs(scores - correct_scores)))
# Out:
# Your scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# correct scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# Difference between your scores and correct scores:
# 3.6802720496109664e-08

# %% [markdown]
# # Forward pass: compute loss
# In the same function, implement the second part that computes the data and regularizaion loss.

# %%
loss, _ = net.loss(X, y, reg=0.05)
correct_loss = 1.30378789133

# should be very small, we get < 1e-12
print('Difference between your loss and correct loss:')
print(np.sum(np.abs(loss - correct_loss)))
# Out:
# Difference between your loss and correct loss:
# 1.794120407794253e-13

# %% [markdown]
# # Backward pass
# Implement the rest of the function. This will compute the gradient of the loss with respect to the variables `W1`, `b1`, `W2`, and `b2`. Now that you (hopefully!) have a correctly implemented forward pass, you can debug your backward pass using a numeric gradient check:

# %%
from cs231n.gradient_check import eval_numerical_gradient

# Use numeric gradient checking to check your implementation of the backward pass.
# If your implementation is correct, the difference between the numeric and
# analytic gradients should be less than 1e-8 for each of W1, W2, b1, and b2.

loss, grads = net.loss(X, y, reg=0.05)

# these should all be less than 1e-8 or so
for param_name in grads:
    f = lambda W: net.loss(X, y, reg=0.05)[0]
    param_grad_num = eval_numerical_gradient(f, net.params[param_name], verbose=False)
    print('%s max relative error: %e' % (param_name, rel_error(param_grad_num, grads[param_name])))
# Out:
# W1 max relative error: 3.561318e-09
# b1 max relative error: 1.125423e-09
# W2 max relative error: 3.440708e-09
# b2 max relative error: 3.865091e-11

# %% [markdown]
# # Train the network
# To train the network we will use stochastic gradient descent (SGD), similar to the SVM and Softmax classifiers. Look at the function `TwoLayerNet.train` and fill in the missing sections to implement the training procedure. This should be very similar to the training procedure you used for the SVM and Softmax classifiers. You will also have to implement `TwoLayerNet.predict`, as the training process periodically performs prediction to keep track of accuracy over time while the network trains.
#
# Once you have implemented the method, run the code below to train a two-layer network on toy data. You should achieve a training loss less than 0.2.

# %%
net = init_toy_model()
stats = net.train(X, y, X, y,
            learning_rate=1e-1, reg=5e-6,
            num_iters=100, verbose=False)

print('Final training loss: ', stats['loss_history'][-1])

# plot the loss history
plt.plot(stats['loss_history'])
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.show()
# Out:
# Final training loss:  0.01714960793873207

# %% [markdown]
# # Load the data
# Now that you have implemented a two-layer network that passes gradient checks and works on toy data, it's time to load up our favorite CIFAR-10 data so we can use it to train a classifier on a real dataset.

# %%
from cs231n.data_utils import load_CIFAR10

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the two-layer neural net classifier. These are the same steps as
    we used for the SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
        
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]

    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis=0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image

    # Reshape data to rows
    X_train = X_train.reshape(num_training, -1)
    X_val = X_val.reshape(num_validation, -1)
    X_test = X_test.reshape(num_test, -1)

    return X_train, y_train, X_val, y_val, X_test, y_test


# Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
try:
   del X_train, y_train
   del X_test, y_test
   print('Clear previously loaded data.')
except:
   pass

# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Train data shape:  (49000, 3072)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3072)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3072)
# Test labels shape:  (1000,)

# %% [markdown]
# # Train a network
# To train our network we will use SGD. In addition, we will adjust the learning rate with an exponential learning rate schedule as optimization proceeds; after each epoch, we will reduce the learning rate by multiplying it by a decay rate.

# %%
input_size = 32 * 32 * 3
hidden_size = 50
num_classes = 10
net = TwoLayerNet(input_size, hidden_size, num_classes)

# Train the network
stats = net.train(X_train, y_train, X_val, y_val,
            num_iters=1000, batch_size=200,
            learning_rate=1e-4, learning_rate_decay=0.95,
            reg=0.25, verbose=True)

# Predict on the validation set
val_acc = (net.predict(X_val) == y_val).mean()
print('Validation accuracy: ', val_acc)
# Out:
# iteration 0 / 1000: loss 2.302954
# iteration 100 / 1000: loss 2.302550
# iteration 200 / 1000: loss 2.297648
# iteration 300 / 1000: loss 2.259602
# iteration 400 / 1000: loss 2.204170
# iteration 500 / 1000: loss 2.118565
# iteration 600 / 1000: loss 2.051535
# iteration 700 / 1000: loss 1.988466
# iteration 800 / 1000: loss 2.006591
# iteration 900 / 1000: loss 1.951473
# Validation accuracy:  0.287

# %% [markdown]
# # Debug the training
# With the default parameters we provided above, you should get a validation accuracy of about 0.29 on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the loss function and the accuracies on the training and validation sets during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
# Plot the loss function and train / validation accuracies
plt.subplot(2, 1, 1)
plt.plot(stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(stats['train_acc_history'], label='train')
plt.plot(stats['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.legend()
plt.show()

# %%
from cs231n.vis_utils import visualize_grid

# Visualize the weights of the network

def show_net_weights(net):
    W1 = net.params['W1']
    W1 = W1.reshape(32, 32, 3, -1).transpose(3, 0, 1, 2)
    plt.imshow(visualize_grid(W1, padding=3).astype('uint8'))
    plt.gca().axis('off')
    plt.show()

show_net_weights(net)

# %% [markdown]
# # Tune your hyperparameters
#
# **What's wrong?**. Looking at the visualizations above, we see that the loss is decreasing more or less linearly, which seems to suggest that the learning rate may be too low. Moreover, there is no gap between the training and validation accuracy, suggesting that the model we used has low capacity, and that we should increase its size. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, numer of training epochs, and regularization strength. You might also consider tuning the learning rate decay, but you should be able to get good performance using the default value.
#
# **Approximate results**. You should be aim to achieve a classification accuracy of greater than 48% on the validation set. Our best network gets over 52% on the validation set.
#
# **Experiment**: You goal in this exercise is to get as good of a result on CIFAR-10 as you can, with a fully-connected Neural Network. Feel free implement your own techniques (e.g. PCA to reduce dimensionality, or adding dropout, or adding features to the solver, etc.).

# %%
best_net = None # store the best model into this 

#################################################################################
# TODO: Tune hyperparameters using the validation set. Store your best trained  #
# model in best_net.                                                            #
#                                                                               #
# To help debug your network, it may help to use visualizations similar to the  #
# ones we used above; these visualizations will have significant qualitative    #
# differences from the ones we saw above for the poorly tuned network.          #
#                                                                               #
# Tweaking hyperparameters by hand can be fun, but you might find it useful to  #
# write code to sweep through possible combinations of hyperparameters          #
# automatically like we did on the previous exercises.                          #
#################################################################################
hidden_sizes = [40, 60, 80, 100, 120]
learning_rates = [1e-4, 5e-4, 1e-3, 5e-3]
reg = [0.2, 0.4, 0.6]

best_acc = -1
input_size = 32 * 32 * 3
hidden_size = 50
num_classes = 10

log = {}
for s in hidden_sizes:
    for lr in learning_rates:
        for r in reg:            
            net = TwoLayerNet(input_size, s, num_classes)

            # Train the network
            stats = net.train(X_train, y_train, X_val, y_val,
                    num_iters=1000, batch_size=200,
                    learning_rate=lr, learning_rate_decay=0.95,
                    reg=r, verbose=True)

            acc = stats['val_acc_history'][-1]
            log[(s, lr, r)] = acc
            
            # Print Log
            print('With s: %e, lr: %e and r: %e, valid accuracy is: %f' 
                    % (s, lr, r, acc))
            
            if acc > best_acc:
                best_net = net
                best_acc = acc
                
print('Best Networks has an Accuracy of: %f' % best_acc)
            
#################################################################################
#                               END OF YOUR CODE                                #
#################################################################################
# Out:
# iteration 0 / 1000: loss 2.302846
# iteration 100 / 1000: loss 2.302561
# iteration 200 / 1000: loss 2.300521
# iteration 300 / 1000: loss 2.269109
# iteration 400 / 1000: loss 2.211656
# iteration 500 / 1000: loss 2.150030
# iteration 600 / 1000: loss 2.081715
# iteration 700 / 1000: loss 1.958256
# iteration 800 / 1000: loss 1.962797
# iteration 900 / 1000: loss 1.983680
# With s: 4.000000e+01, lr: 1.000000e-04 and r: 2.000000e-01, valid accuracy is: 0.289000
# iteration 0 / 1000: loss 2.303086
# iteration 100 / 1000: loss 2.302606
# iteration 200 / 1000: loss 2.297498
# iteration 300 / 1000: loss 2.275409
# iteration 400 / 1000: loss 2.182129
# iteration 500 / 1000: loss 2.116110
# iteration 600 / 1000: loss 2.090851
# iteration 700 / 1000: loss 2.083274
# iteration 800 / 1000: loss 2.064404
# iteration 900 / 1000: loss 1.999980
# With s: 4.000000e+01, lr: 1.000000e-04 and r: 4.000000e-01, valid accuracy is: 0.286000
# iteration 0 / 1000: loss 2.303325
# iteration 100 / 1000: loss 2.303083
# iteration 200 / 1000: loss 2.300461
# iteration 300 / 1000: loss 2.281554
# iteration 400 / 1000: loss 2.223677
# iteration 500 / 1000: loss 2.084139
# iteration 600 / 1000: loss 2.069842
# iteration 700 / 1000: loss 2.099904
# iteration 800 / 1000: loss 1.922837
# iteration 900 / 1000: loss 1.905508
# With s: 4.000000e+01, lr: 1.000000e-04 and r: 6.000000e-01, valid accuracy is: 0.279000
# iteration 0 / 1000: loss 2.302842
# iteration 100 / 1000: loss 2.138521
# iteration 200 / 1000: loss 2.016198
# iteration 300 / 1000: loss 1.906428
# iteration 400 / 1000: loss 1.826257
# iteration 500 / 1000: loss 1.836061
# iteration 600 / 1000: loss 1.837456
# iteration 700 / 1000: loss 1.719809
# iteration 800 / 1000: loss 1.633282
# iteration 900 / 1000: loss 1.580999
# With s: 4.000000e+01, lr: 5.000000e-04 and r: 2.000000e-01, valid accuracy is: 0.451000
# iteration 0 / 1000: loss 2.303049
# iteration 100 / 1000: loss 2.161152
# iteration 200 / 1000: loss 1.958841
# iteration 300 / 1000: loss 1.915495
# iteration 400 / 1000: loss 1.734237
# iteration 500 / 1000: loss 1.707481
# iteration 600 / 1000: loss 1.768213
# iteration 700 / 1000: loss 1.680116
# iteration 800 / 1000: loss 1.668979
# iteration 900 / 1000: loss 1.541229
# With s: 4.000000e+01, lr: 5.000000e-04 and r: 4.000000e-01, valid accuracy is: 0.452000
# iteration 0 / 1000: loss 2.303317
# iteration 100 / 1000: loss 2.089908
# iteration 200 / 1000: loss 1.881864
# iteration 300 / 1000: loss 1.958857
# iteration 400 / 1000: loss 1.737695
# iteration 500 / 1000: loss 1.775110
# iteration 600 / 1000: loss 1.738364
# iteration 700 / 1000: loss 1.639206
# iteration 800 / 1000: loss 1.635091
# iteration 900 / 1000: loss 1.685950
# With s: 4.000000e+01, lr: 5.000000e-04 and r: 6.000000e-01, valid accuracy is: 0.431000
# iteration 0 / 1000: loss 2.302848
# iteration 100 / 1000: loss 1.932937
# iteration 200 / 1000: loss 1.774808
# iteration 300 / 1000: loss 1.652238
# iteration 400 / 1000: loss 1.686532
# iteration 500 / 1000: loss 1.583196
# iteration 600 / 1000: loss 1.586301
# iteration 700 / 1000: loss 1.462557
# iteration 800 / 1000: loss 1.581116
# iteration 900 / 1000: loss 1.471460
# With s: 4.000000e+01, lr: 1.000000e-03 and r: 2.000000e-01, valid accuracy is: 0.484000
# iteration 0 / 1000: loss 2.303102
# iteration 100 / 1000: loss 1.975213
# iteration 200 / 1000: loss 1.824451
# iteration 300 / 1000: loss 1.628936
# iteration 400 / 1000: loss 1.677104
# iteration 500 / 1000: loss 1.707673
# iteration 600 / 1000: loss 1.638547
# iteration 700 / 1000: loss 1.531885
# iteration 800 / 1000: loss 1.557557
# iteration 900 / 1000: loss 1.491817
# With s: 4.000000e+01, lr: 1.000000e-03 and r: 4.000000e-01, valid accuracy is: 0.470000
# iteration 0 / 1000: loss 2.303328
# iteration 100 / 1000: loss 2.008915
# iteration 200 / 1000: loss 1.739691
# iteration 300 / 1000: loss 1.739944
# iteration 400 / 1000: loss 1.722101
# iteration 500 / 1000: loss 1.676212
# iteration 600 / 1000: loss 1.625167
# iteration 700 / 1000: loss 1.564506
# iteration 800 / 1000: loss 1.658367
# iteration 900 / 1000: loss 1.695677
# With s: 4.000000e+01, lr: 1.000000e-03 and r: 6.000000e-01, valid accuracy is: 0.461000
# iteration 0 / 1000: loss 2.302835
# C:\Users\NGUYENVANHUNG\Desktop\My file\python\assignment1\cs231n\classifiers\neural_net.py:100: RuntimeWarning: invalid value encountered in true_divide
#   scores /= np.sum(scores, axis=1).reshape(-1, 1)
# C:\Users\NGUYENVANHUNG\Desktop\My file\python\assignment1\cs231n\classifiers\neural_net.py:101: RuntimeWarning: divide by zero encountered in log
#   loss = -(1)/num_train * np.sum(np.log(scores[range(N), y])) + 0.5 * reg * (np.sum(W1**2) + np.sum(W2**2))
# C:\Users\NGUYENVANHUNG\Desktop\My file\python\assignment1\cs231n\classifiers\neural_net.py:79: RuntimeWarning: invalid value encountered in maximum
#   A1 = np.maximum(0, Z1)
# C:\Users\NGUYENVANHUNG\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\_methods.py:28: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial)
# C:\Users\NGUYENVANHUNG\Desktop\My file\python\assignment1\cs231n\classifiers\neural_net.py:120: RuntimeWarning: invalid value encountered in less
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# C:\Users\NGUYENVANHUNG\Desktop\My file\python\assignment1\cs231n\classifiers\neural_net.py:239: RuntimeWarning: invalid value encountered in maximum
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# With s: 4.000000e+01, lr: 5.000000e-03 and r: 2.000000e-01, valid accuracy is: 0.087000
# iteration 0 / 1000: loss 2.303092
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# With s: 4.000000e+01, lr: 5.000000e-03 and r: 4.000000e-01, valid accuracy is: 0.087000
# iteration 0 / 1000: loss 2.303364
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# With s: 4.000000e+01, lr: 5.000000e-03 and r: 6.000000e-01, valid accuracy is: 0.087000
# iteration 0 / 1000: loss 2.302944
# iteration 100 / 1000: loss 2.302434
# iteration 200 / 1000: loss 2.296137
# iteration 300 / 1000: loss 2.257064
# iteration 400 / 1000: loss 2.194061
# iteration 500 / 1000: loss 2.093394
# iteration 600 / 1000: loss 1.995696
# iteration 700 / 1000: loss 2.086529
# iteration 800 / 1000: loss 2.009872
# iteration 900 / 1000: loss 2.015297
# With s: 6.000000e+01, lr: 1.000000e-04 and r: 2.000000e-01, valid accuracy is: 0.280000
# iteration 0 / 1000: loss 2.303347
# iteration 100 / 1000: loss 2.302863
# iteration 200 / 1000: loss 2.298725
# iteration 300 / 1000: loss 2.244604
# iteration 400 / 1000: loss 2.191772
# iteration 500 / 1000: loss 2.087919
# iteration 600 / 1000: loss 2.128166
# iteration 700 / 1000: loss 2.020239
# iteration 800 / 1000: loss 2.007022
# iteration 900 / 1000: loss 2.079199
# With s: 6.000000e+01, lr: 1.000000e-04 and r: 4.000000e-01, valid accuracy is: 0.277000
# iteration 0 / 1000: loss 2.303681
# iteration 100 / 1000: loss 2.303090
# iteration 200 / 1000: loss 2.300409
# iteration 300 / 1000: loss 2.265187
# iteration 400 / 1000: loss 2.193611
# iteration 500 / 1000: loss 2.054987
# iteration 600 / 1000: loss 2.089660
# iteration 700 / 1000: loss 2.085753
# iteration 800 / 1000: loss 2.022593
# iteration 900 / 1000: loss 2.004781
# With s: 6.000000e+01, lr: 1.000000e-04 and r: 6.000000e-01, valid accuracy is: 0.278000
# iteration 0 / 1000: loss 2.302948
# iteration 100 / 1000: loss 2.121085
# iteration 200 / 1000: loss 1.896155
# iteration 300 / 1000: loss 1.759774
# iteration 400 / 1000: loss 1.803663
# iteration 500 / 1000: loss 1.730230
# iteration 600 / 1000: loss 1.589264
# iteration 700 / 1000: loss 1.673668
# iteration 800 / 1000: loss 1.673258
# iteration 900 / 1000: loss 1.620087
# With s: 6.000000e+01, lr: 5.000000e-04 and r: 2.000000e-01, valid accuracy is: 0.451000
# iteration 0 / 1000: loss 2.303315
# iteration 100 / 1000: loss 2.104382
# iteration 200 / 1000: loss 1.830547
# iteration 300 / 1000: loss 1.883813
# iteration 400 / 1000: loss 1.689823
# iteration 500 / 1000: loss 1.712078
# iteration 600 / 1000: loss 1.643112
# iteration 700 / 1000: loss 1.607537
# iteration 800 / 1000: loss 1.641612
# iteration 900 / 1000: loss 1.617106
# With s: 6.000000e+01, lr: 5.000000e-04 and r: 4.000000e-01, valid accuracy is: 0.443000
# iteration 0 / 1000: loss 2.303716
# iteration 100 / 1000: loss 2.067557
# iteration 200 / 1000: loss 1.971919
# iteration 300 / 1000: loss 1.854852
# iteration 400 / 1000: loss 1.810532
# iteration 500 / 1000: loss 1.833804
# iteration 600 / 1000: loss 1.739771
# iteration 700 / 1000: loss 1.728254
# iteration 800 / 1000: loss 1.721938
# iteration 900 / 1000: loss 1.747821
# With s: 6.000000e+01, lr: 5.000000e-04 and r: 6.000000e-01, valid accuracy is: 0.436000
# iteration 0 / 1000: loss 2.302940
# iteration 100 / 1000: loss 1.896413
# iteration 200 / 1000: loss 1.833692
# iteration 300 / 1000: loss 1.682888
# iteration 400 / 1000: loss 1.692670
# iteration 500 / 1000: loss 1.750936
# iteration 600 / 1000: loss 1.629456
# iteration 700 / 1000: loss 1.520290
# iteration 800 / 1000: loss 1.707384
# iteration 900 / 1000: loss 1.544725
# With s: 6.000000e+01, lr: 1.000000e-03 and r: 2.000000e-01, valid accuracy is: 0.441000
# iteration 0 / 1000: loss 2.303366
# iteration 100 / 1000: loss 1.884910
# iteration 200 / 1000: loss 1.801642
# iteration 300 / 1000: loss 1.802249
# iteration 400 / 1000: loss 1.683717
# iteration 500 / 1000: loss 1.570177
# iteration 600 / 1000: loss 1.653455
# iteration 700 / 1000: loss 1.603204
# iteration 800 / 1000: loss 1.653186
# iteration 900 / 1000: loss 1.489848
# With s: 6.000000e+01, lr: 1.000000e-03 and r: 4.000000e-01, valid accuracy is: 0.465000
# iteration 0 / 1000: loss 2.303686
# iteration 100 / 1000: loss 2.028243
# iteration 200 / 1000: loss 1.804077
# iteration 300 / 1000: loss 1.741717
# iteration 400 / 1000: loss 1.771786
# iteration 500 / 1000: loss 1.639584
# iteration 600 / 1000: loss 1.609098
# iteration 700 / 1000: loss 1.624935
# iteration 800 / 1000: loss 1.604387
# iteration 900 / 1000: loss 1.560820
# With s: 6.000000e+01, lr: 1.000000e-03 and r: 6.000000e-01, valid accuracy is: 0.469000
# iteration 0 / 1000: loss 2.302947
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# With s: 6.000000e+01, lr: 5.000000e-03 and r: 2.000000e-01, valid accuracy is: 0.087000
# iteration 0 / 1000: loss 2.303326
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# With s: 6.000000e+01, lr: 5.000000e-03 and r: 4.000000e-01, valid accuracy is: 0.087000
# iteration 0 / 1000: loss 2.303708
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# With s: 6.000000e+01, lr: 5.000000e-03 and r: 6.000000e-01, valid accuracy is: 0.087000
# iteration 0 / 1000: loss 2.303081
# iteration 100 / 1000: loss 2.302318
# iteration 200 / 1000: loss 2.296730
# iteration 300 / 1000: loss 2.221847
# iteration 400 / 1000: loss 2.183068
# iteration 500 / 1000: loss 2.099381
# iteration 600 / 1000: loss 2.070650
# iteration 700 / 1000: loss 1.967769
# iteration 800 / 1000: loss 2.008925
# iteration 900 / 1000: loss 1.969587
# With s: 8.000000e+01, lr: 1.000000e-04 and r: 2.000000e-01, valid accuracy is: 0.290000
# iteration 0 / 1000: loss 2.303590
# iteration 100 / 1000: loss 2.303191
# iteration 200 / 1000: loss 2.298218
# iteration 300 / 1000: loss 2.268230
# iteration 400 / 1000: loss 2.186884
# iteration 500 / 1000: loss 2.129622
# iteration 600 / 1000: loss 2.074341
# iteration 700 / 1000: loss 1.996807
# iteration 800 / 1000: loss 1.991158
# iteration 900 / 1000: loss 2.001261
# With s: 8.000000e+01, lr: 1.000000e-04 and r: 4.000000e-01, valid accuracy is: 0.289000
# iteration 0 / 1000: loss 2.304066
# iteration 100 / 1000: loss 2.303447
# iteration 200 / 1000: loss 2.298725
# iteration 300 / 1000: loss 2.261447
# iteration 400 / 1000: loss 2.175945
# iteration 500 / 1000: loss 2.160759
# iteration 600 / 1000: loss 2.068099
# iteration 700 / 1000: loss 2.107110
# iteration 800 / 1000: loss 1.991074
# iteration 900 / 1000: loss 1.924108
# With s: 8.000000e+01, lr: 1.000000e-04 and r: 6.000000e-01, valid accuracy is: 0.282000
# iteration 0 / 1000: loss 2.303093
# iteration 100 / 1000: loss 2.055289
# iteration 200 / 1000: loss 1.974936
# iteration 300 / 1000: loss 1.772310
# iteration 400 / 1000: loss 1.780236
# iteration 500 / 1000: loss 1.747639
# iteration 600 / 1000: loss 1.668158
# iteration 700 / 1000: loss 1.648137
# iteration 800 / 1000: loss 1.612373
# iteration 900 / 1000: loss 1.629326
# With s: 8.000000e+01, lr: 5.000000e-04 and r: 2.000000e-01, valid accuracy is: 0.462000
# iteration 0 / 1000: loss 2.303565
# iteration 100 / 1000: loss 2.086056
# iteration 200 / 1000: loss 1.961599
# iteration 300 / 1000: loss 1.865599
# iteration 400 / 1000: loss 1.673687
# iteration 500 / 1000: loss 1.749477
# iteration 600 / 1000: loss 1.680512
# iteration 700 / 1000: loss 1.813898
# iteration 800 / 1000: loss 1.683733
# iteration 900 / 1000: loss 1.601257
# With s: 8.000000e+01, lr: 5.000000e-04 and r: 4.000000e-01, valid accuracy is: 0.445000
# iteration 0 / 1000: loss 2.304066
# iteration 100 / 1000: loss 2.125127
# iteration 200 / 1000: loss 1.955522
# iteration 300 / 1000: loss 1.810765
# iteration 400 / 1000: loss 1.715612
# iteration 500 / 1000: loss 1.678823
# iteration 600 / 1000: loss 1.762845
# iteration 700 / 1000: loss 1.716971
# iteration 800 / 1000: loss 1.658305
# iteration 900 / 1000: loss 1.698083
# With s: 8.000000e+01, lr: 5.000000e-04 and r: 6.000000e-01, valid accuracy is: 0.454000
# iteration 0 / 1000: loss 2.303063
# iteration 100 / 1000: loss 1.920743
# iteration 200 / 1000: loss 1.772157
# iteration 300 / 1000: loss 1.746183
# iteration 400 / 1000: loss 1.522679
# iteration 500 / 1000: loss 1.616347
# iteration 600 / 1000: loss 1.634587
# iteration 700 / 1000: loss 1.586939
# iteration 800 / 1000: loss 1.422360
# iteration 900 / 1000: loss 1.369637
# With s: 8.000000e+01, lr: 1.000000e-03 and r: 2.000000e-01, valid accuracy is: 0.469000
# iteration 0 / 1000: loss 2.303570
# iteration 100 / 1000: loss 1.905688
# iteration 200 / 1000: loss 1.813813
# iteration 300 / 1000: loss 1.711720
# iteration 400 / 1000: loss 1.590981
# iteration 500 / 1000: loss 1.693490
# iteration 600 / 1000: loss 1.657648
# iteration 700 / 1000: loss 1.477932
# iteration 800 / 1000: loss 1.606148
# iteration 900 / 1000: loss 1.558284
# With s: 8.000000e+01, lr: 1.000000e-03 and r: 4.000000e-01, valid accuracy is: 0.475000
# iteration 0 / 1000: loss 2.304068
# iteration 100 / 1000: loss 1.939879
# iteration 200 / 1000: loss 1.717868
# iteration 300 / 1000: loss 1.719652
# iteration 400 / 1000: loss 1.627418
# iteration 500 / 1000: loss 1.679846
# iteration 600 / 1000: loss 1.771428
# iteration 700 / 1000: loss 1.618561
# iteration 800 / 1000: loss 1.639431
# iteration 900 / 1000: loss 1.661809
# With s: 8.000000e+01, lr: 1.000000e-03 and r: 6.000000e-01, valid accuracy is: 0.473000
# iteration 0 / 1000: loss 2.303060
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# With s: 8.000000e+01, lr: 5.000000e-03 and r: 2.000000e-01, valid accuracy is: 0.087000
# iteration 0 / 1000: loss 2.303590
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# With s: 8.000000e+01, lr: 5.000000e-03 and r: 4.000000e-01, valid accuracy is: 0.087000
# iteration 0 / 1000: loss 2.304068
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# With s: 8.000000e+01, lr: 5.000000e-03 and r: 6.000000e-01, valid accuracy is: 0.087000
# iteration 0 / 1000: loss 2.303214
# iteration 100 / 1000: loss 2.302136
# iteration 200 / 1000: loss 2.292554
# iteration 300 / 1000: loss 2.219398
# iteration 400 / 1000: loss 2.169262
# iteration 500 / 1000: loss 2.112563
# iteration 600 / 1000: loss 2.029313
# iteration 700 / 1000: loss 2.059013
# iteration 800 / 1000: loss 1.948746
# iteration 900 / 1000: loss 1.886486
# With s: 1.000000e+02, lr: 1.000000e-04 and r: 2.000000e-01, valid accuracy is: 0.294000
# iteration 0 / 1000: loss 2.303848
# iteration 100 / 1000: loss 2.303032
# iteration 200 / 1000: loss 2.293654
# iteration 300 / 1000: loss 2.242740
# iteration 400 / 1000: loss 2.171931
# iteration 500 / 1000: loss 2.180064
# iteration 600 / 1000: loss 2.043577
# iteration 700 / 1000: loss 2.059897
# iteration 800 / 1000: loss 1.944772
# iteration 900 / 1000: loss 1.973997
# With s: 1.000000e+02, lr: 1.000000e-04 and r: 4.000000e-01, valid accuracy is: 0.280000
# iteration 0 / 1000: loss 2.304433
# iteration 100 / 1000: loss 2.303282
# iteration 200 / 1000: loss 2.295357
# iteration 300 / 1000: loss 2.233127
# iteration 400 / 1000: loss 2.179559
# iteration 500 / 1000: loss 2.078688
# iteration 600 / 1000: loss 2.131392
# iteration 700 / 1000: loss 2.057413
# iteration 800 / 1000: loss 2.021935
# iteration 900 / 1000: loss 1.990397
# With s: 1.000000e+02, lr: 1.000000e-04 and r: 6.000000e-01, valid accuracy is: 0.290000
# iteration 0 / 1000: loss 2.303203
# iteration 100 / 1000: loss 2.073183
# iteration 200 / 1000: loss 1.913032
# iteration 300 / 1000: loss 1.856227
# iteration 400 / 1000: loss 1.745909
# iteration 500 / 1000: loss 1.671705
# iteration 600 / 1000: loss 1.653006
# iteration 700 / 1000: loss 1.585632
# iteration 800 / 1000: loss 1.608966
# iteration 900 / 1000: loss 1.741418
# With s: 1.000000e+02, lr: 5.000000e-04 and r: 2.000000e-01, valid accuracy is: 0.476000
# iteration 0 / 1000: loss 2.303791
# iteration 100 / 1000: loss 2.119617
# iteration 200 / 1000: loss 1.868202
# iteration 300 / 1000: loss 1.777411
# iteration 400 / 1000: loss 1.752634
# iteration 500 / 1000: loss 1.673146
# iteration 600 / 1000: loss 1.641325
# iteration 700 / 1000: loss 1.662729
# iteration 800 / 1000: loss 1.527450
# iteration 900 / 1000: loss 1.619955
# With s: 1.000000e+02, lr: 5.000000e-04 and r: 4.000000e-01, valid accuracy is: 0.454000
# iteration 0 / 1000: loss 2.304451
# iteration 100 / 1000: loss 2.058534
# iteration 200 / 1000: loss 1.892873
# iteration 300 / 1000: loss 1.866883
# iteration 400 / 1000: loss 1.848978
# iteration 500 / 1000: loss 1.791753
# iteration 600 / 1000: loss 1.667490
# iteration 700 / 1000: loss 1.752668
# iteration 800 / 1000: loss 1.726660
# iteration 900 / 1000: loss 1.633400
# With s: 1.000000e+02, lr: 5.000000e-04 and r: 6.000000e-01, valid accuracy is: 0.463000
# iteration 0 / 1000: loss 2.303233
# iteration 100 / 1000: loss 1.922283
# iteration 200 / 1000: loss 1.808038
# iteration 300 / 1000: loss 1.747323
# iteration 400 / 1000: loss 1.625444
# iteration 500 / 1000: loss 1.592814
# iteration 600 / 1000: loss 1.456548
# iteration 700 / 1000: loss 1.330032
# iteration 800 / 1000: loss 1.615734
# iteration 900 / 1000: loss 1.467468
# With s: 1.000000e+02, lr: 1.000000e-03 and r: 2.000000e-01, valid accuracy is: 0.473000
# iteration 0 / 1000: loss 2.303807
# iteration 100 / 1000: loss 1.923595
# iteration 200 / 1000: loss 1.805025
# iteration 300 / 1000: loss 1.681745
# iteration 400 / 1000: loss 1.743798
# iteration 500 / 1000: loss 1.692467
# iteration 600 / 1000: loss 1.591225
# iteration 700 / 1000: loss 1.525047
# iteration 800 / 1000: loss 1.487907
# iteration 900 / 1000: loss 1.452891
# With s: 1.000000e+02, lr: 1.000000e-03 and r: 4.000000e-01, valid accuracy is: 0.466000
# iteration 0 / 1000: loss 2.304427
# iteration 100 / 1000: loss 1.921033
# iteration 200 / 1000: loss 1.778843
# iteration 300 / 1000: loss 1.593561
# iteration 400 / 1000: loss 1.702631
# iteration 500 / 1000: loss 1.570096
# iteration 600 / 1000: loss 1.694855
# iteration 700 / 1000: loss 1.621051
# iteration 800 / 1000: loss 1.520721
# iteration 900 / 1000: loss 1.681306
# With s: 1.000000e+02, lr: 1.000000e-03 and r: 6.000000e-01, valid accuracy is: 0.467000
# iteration 0 / 1000: loss 2.303174
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# With s: 1.000000e+02, lr: 5.000000e-03 and r: 2.000000e-01, valid accuracy is: 0.087000
# iteration 0 / 1000: loss 2.303817
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# With s: 1.000000e+02, lr: 5.000000e-03 and r: 4.000000e-01, valid accuracy is: 0.087000
# iteration 0 / 1000: loss 2.304453
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# With s: 1.000000e+02, lr: 5.000000e-03 and r: 6.000000e-01, valid accuracy is: 0.087000
# iteration 0 / 1000: loss 2.303279
# iteration 100 / 1000: loss 2.302042
# iteration 200 / 1000: loss 2.290091
# iteration 300 / 1000: loss 2.217598
# iteration 400 / 1000: loss 2.215196
# iteration 500 / 1000: loss 2.003524
# iteration 600 / 1000: loss 2.031563
# iteration 700 / 1000: loss 2.034842
# iteration 800 / 1000: loss 1.967051
# iteration 900 / 1000: loss 1.913158
# With s: 1.200000e+02, lr: 1.000000e-04 and r: 2.000000e-01, valid accuracy is: 0.290000
# iteration 0 / 1000: loss 2.303998
# iteration 100 / 1000: loss 2.302743
# iteration 200 / 1000: loss 2.292806
# iteration 300 / 1000: loss 2.192050
# iteration 400 / 1000: loss 2.132807
# iteration 500 / 1000: loss 2.045886
# iteration 600 / 1000: loss 2.032241
# iteration 700 / 1000: loss 2.102937
# iteration 800 / 1000: loss 1.948212
# iteration 900 / 1000: loss 1.961879
# With s: 1.200000e+02, lr: 1.000000e-04 and r: 4.000000e-01, valid accuracy is: 0.292000
# iteration 0 / 1000: loss 2.304811
# iteration 100 / 1000: loss 2.303913
# iteration 200 / 1000: loss 2.293267
# iteration 300 / 1000: loss 2.242545
# iteration 400 / 1000: loss 2.107016
# iteration 500 / 1000: loss 2.087163
# iteration 600 / 1000: loss 2.086327
# iteration 700 / 1000: loss 2.020780
# iteration 800 / 1000: loss 1.947017
# iteration 900 / 1000: loss 2.028565
# With s: 1.200000e+02, lr: 1.000000e-04 and r: 6.000000e-01, valid accuracy is: 0.288000
# iteration 0 / 1000: loss 2.303338
# iteration 100 / 1000: loss 2.085183
# iteration 200 / 1000: loss 1.881940
# iteration 300 / 1000: loss 1.806049
# iteration 400 / 1000: loss 1.710116
# iteration 500 / 1000: loss 1.688582
# iteration 600 / 1000: loss 1.486028
# iteration 700 / 1000: loss 1.706710
# iteration 800 / 1000: loss 1.665960
# iteration 900 / 1000: loss 1.572967
# With s: 1.200000e+02, lr: 5.000000e-04 and r: 2.000000e-01, valid accuracy is: 0.451000
# iteration 0 / 1000: loss 2.304069
# iteration 100 / 1000: loss 2.061470
# iteration 200 / 1000: loss 1.952494
# iteration 300 / 1000: loss 1.849028
# iteration 400 / 1000: loss 1.810628
# iteration 500 / 1000: loss 1.677584
# iteration 600 / 1000: loss 1.667068
# iteration 700 / 1000: loss 1.750305
# iteration 800 / 1000: loss 1.639111
# iteration 900 / 1000: loss 1.649230
# With s: 1.200000e+02, lr: 5.000000e-04 and r: 4.000000e-01, valid accuracy is: 0.459000
# iteration 0 / 1000: loss 2.304799
# iteration 100 / 1000: loss 2.073051
# iteration 200 / 1000: loss 1.923634
# iteration 300 / 1000: loss 1.844922
# iteration 400 / 1000: loss 1.773384
# iteration 500 / 1000: loss 1.740162
# iteration 600 / 1000: loss 1.725206
# iteration 700 / 1000: loss 1.660932
# iteration 800 / 1000: loss 1.648590
# iteration 900 / 1000: loss 1.701823
# With s: 1.200000e+02, lr: 5.000000e-04 and r: 6.000000e-01, valid accuracy is: 0.446000
# iteration 0 / 1000: loss 2.303349
# iteration 100 / 1000: loss 1.873421
# iteration 200 / 1000: loss 1.819767
# iteration 300 / 1000: loss 1.638421
# iteration 400 / 1000: loss 1.598389
# iteration 500 / 1000: loss 1.624879
# iteration 600 / 1000: loss 1.597976
# iteration 700 / 1000: loss 1.556484
# iteration 800 / 1000: loss 1.567086
# iteration 900 / 1000: loss 1.477734
# With s: 1.200000e+02, lr: 1.000000e-03 and r: 2.000000e-01, valid accuracy is: 0.468000
# iteration 0 / 1000: loss 2.304077
# iteration 100 / 1000: loss 1.999468
# iteration 200 / 1000: loss 1.762214
# iteration 300 / 1000: loss 1.664227
# iteration 400 / 1000: loss 1.521643
# iteration 500 / 1000: loss 1.685989
# iteration 600 / 1000: loss 1.615353
# iteration 700 / 1000: loss 1.525052
# iteration 800 / 1000: loss 1.560465
# iteration 900 / 1000: loss 1.503499
# With s: 1.200000e+02, lr: 1.000000e-03 and r: 4.000000e-01, valid accuracy is: 0.442000
# iteration 0 / 1000: loss 2.304788
# iteration 100 / 1000: loss 1.880369
# iteration 200 / 1000: loss 1.853549
# iteration 300 / 1000: loss 1.693411
# iteration 400 / 1000: loss 1.532166
# iteration 500 / 1000: loss 1.546964
# iteration 600 / 1000: loss 1.719628
# iteration 700 / 1000: loss 1.595530
# iteration 800 / 1000: loss 1.494585
# iteration 900 / 1000: loss 1.525410
# With s: 1.200000e+02, lr: 1.000000e-03 and r: 6.000000e-01, valid accuracy is: 0.464000
# iteration 0 / 1000: loss 2.303313
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# With s: 1.200000e+02, lr: 5.000000e-03 and r: 2.000000e-01, valid accuracy is: 0.087000
# iteration 0 / 1000: loss 2.304086
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# With s: 1.200000e+02, lr: 5.000000e-03 and r: 4.000000e-01, valid accuracy is: 0.087000
# iteration 0 / 1000: loss 2.304810
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# With s: 1.200000e+02, lr: 5.000000e-03 and r: 6.000000e-01, valid accuracy is: 0.087000
# Best Networks has an Accuracy of: 0.484000

# %%
# visualize the weights of the best network
show_net_weights(best_net)

# %% [markdown]
# # Run on the test set
# When you are done experimenting, you should evaluate your final trained network on the test set; you should get above 48%.

# %%
test_acc = (best_net.predict(X_test) == y_test).mean()
print('Test accuracy: ', test_acc)
# Out:
# Test accuracy:  0.466
